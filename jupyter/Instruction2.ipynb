# %%
print('hello')
# Out:
# hello

# %% [markdown]
# $x^3$ + $x^2$

# %% [markdown]
# Instruction to use jupyter

# %% [markdown]
# Dấu $$ in ra giữa $$

# %% [markdown]
# $$
# \frac{f(x)}{g(x)}\\
# x^4\\
# A_i\\
# B_{ij}\\
# \sqrt[n]{f(x)}
# \sqrt[3]{g(x)}\\
# \sqrt[n]{f(x)}\\
# \sqrt[3]{g(x)}
# $$

# %% [markdown]
# - List 1
# 1. List 1

# %% [markdown]
# # HEADING 1
# ## HEADING 2
# ### HEADING 3

# %%
l=[1,'string',[1,2,3]]
print(l)
# Out:
# [1, 'string', [1, 2, 3]]

# %%
for i in l:
    print(i)
for i in range(len(l)):
    print(l[i])
# Out:
# 1
# string
# [1, 2, 3]
# 1
# string
# [1, 2, 3]

# %%
t=('apple','bottle','car')
type(t)
# Out:
# tuple

# %%
t[0]
# Out:
# 'apple'

# %%
t[0]='dog'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 t[0]='dog'
#
# TypeError: 'tuple' object does not support item assignment

# %%
t=('apple',)
len(t)
# Out:
# 1

# %%
#dictoinaries
d={'a':1,'b':2}

# %%
d['a']
# Out:
# 1

# %%
d['b']
# Out:
# 2

# %%
d['c']=3

# %%
d
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
d.items()
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 3)])

# %%
d.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
d.values()
# Out:
# dict_values([1, 2, 3])
