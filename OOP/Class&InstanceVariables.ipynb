# %%
from car import Car
#an object is a bundle of related attributes(variables) and method (functions)
#attributes are variables that an object has
#method are functions that belong to an object they define what this object can do
car1= Car("Lamborgini",2026,"black",False)
car2= Car("Corvette",2027,"blue",True)

print(car1.year)
print(car2.model)
print(car1.color)
print(car2.for_sale)

car1.drive()
car2.drive()
car1.stop()
car2.stop()
# Out:
# 2026
# Corvette
# black
# True
# You can drive the black Lamborgini in 2026
# You can drive the blue Corvette in 2027
# You must stop the black Lamborgini in 2026
# You must stop the blue Corvette in 2027

# %%
# class variables = Shared among all instances of a class
#            Defined outside the constructor
#            Allow you to share data among all objects created from that class
class Student:
    class_year=2026 #class variables
    num_students=0
    def __init__(self,name,age):
        self.name=name # Instance variables
        self.age=age
        Student.num_students+=1

student1=Student("Hoang",19)
student2=Student("Dat",25)
student3=Student("Toan",28)

print(student1.name)
print(student2.name)

print(Student.class_year)
print(Student.num_students)

print(f"My graduated class of {Student.class_year} has {Student.num_students} students")
# Out:
# Hoang
# Dat
# 2026
# 3
# My graduated class of 2026 has 3 students
