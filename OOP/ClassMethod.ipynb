# %%
class Student:
    count=0
    total_gpa=0
    def __init__(self,name,gpa):
        self.name=name
        self.gpa=gpa
        Student.count+=1
        Student.total_gpa+=gpa
    #Instance method
    def get_info(self):
        return f"{self.name} {self.gpa}"
    @classmethod
    def get_count(cls):
        return f"Total of students : {cls.count}"
    @classmethod
    def get_average_gpa(cls):
        return f"The average age at all students : {cls.total_gpa/cls.count:.2f}"
student1=Student("Hoang",3.5)
student2=Student("Phuc",3.45)
student3=Student("Trung",3.35)
print(Student.get_count())
print(Student.get_average_gpa())
# Out:
# Total of students : 3
# The average age at all students : 3.43

# %%
class Student:
    school = "MIT"

    def instance_method(self):
        print("Instance method")

    @classmethod
    def class_method(cls):
        print("Class method")

    @staticmethod
    def static_method():
        print("Static method")
